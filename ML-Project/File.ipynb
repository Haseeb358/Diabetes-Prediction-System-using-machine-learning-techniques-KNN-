# %% [markdown]
# # 📁 ML Project
#
# ## 👥 Team Members:
# - **Muhammad Haseeb Shoukat** : **0015-BSCS-22**
# - **Mehdi Raza** : **0025-BSCS-22**
#
# ---
#
# ## 📊 Information About Dataset
#
# The **Diabetes prediction dataset** is a collection of medical and demographic data from patients, along with their diabetes status (positive or negative). The data includes features such as **age, gender, body mass index (BMI), hypertension, heart disease, smoking history, HbA1c level, and blood glucose level**.
#
# This dataset can be used to build machine learning models to **predict diabetes** in patients based on their medical history and demographic information. This can be useful for healthcare professionals in identifying patients who may be at risk of developing diabetes and in developing personalized treatment plans.
#
# Additionally, the dataset can be used by researchers to **explore the relationships** between various medical and demographic factors and the likelihood of developing diabetes.
#
# ---
#
# ## 🧬 Features of Dataset
#
# - **Gender**: Biological sex of the individual.
#   - Categories: `Male`, `Female`, `Others`
#
# - **Age**: Important factor; diabetes is more common in older adults.
#   - Ranges from **0 to 80** in our dataset.
#
# - **Hypertension**:  Hypertension is a medical condition in which the blood pressure in the arteries is persistently elevated
#   - `0` = No hypertension
#   - `1` = Has hypertension
#   - High blood pressure may increase diabetes risk.
#
# - **Heart Disease**:
#   - `0` = No heart disease
#   - `1` = Has heart disease
#   - Heart issues are associated with higher diabetes risk.
#
# - **Smoking History**: Important risk factor. Categories:
#   - `Never`: Never smoked
#   - `No Info`: Unknown smoking history
#   - `Current`: Currently smokes
#   - `Former`: Smoked before, now quit
#   - `Ever`: Smoked at some point (current or past)
#   - `Not Current`: Not currently smoking, might have in past
#
# - **BMI (Body Mass Index)**: Measures body fat from height and weight.
#   - Range: **10.16 – 71.55**
#   - Categories:
#     - Underweight: < 18.5
#     - Normal: 18.5–24.9
#     - Overweight: 25–29.9
#     - Obese: 30+
#
# - **HbA1c Level**: HbA1c (Hemoglobin A1c) level is a measure of a person's average blood sugar level over the past 2-3 months.
#   - Typically, **>6.5% indicates diabetes risk**
#
# - **Blood Glucose Level**: Amount of sugar in the blood at a specific moment.
#
# - **Diabetes** *(Target Variable)*:
#   - `1` = Patient has diabetes
#   - `0` = Patient does not have diabetes

# %% [markdown]
# # 🔍 Exploratory Data Analysis (EDA)
#
# ## 📌 Objective:
# The goal of EDA is to understand the structure, patterns, and relationships in the dataset before applying any machine learning models. It helps identify missing values, outliers, feature distributions, and correlations between variables.

# %% [markdown]
# ### 1. **Basic Information**
# - Loaded the dataset using
# - Viewed the first few rows using
# - Viewed the last few rows using
# - Checked the shape of the dataset with `df.shape`.
# - Reviewed data types and null values using `df.info()`
# - Checked which columns contain missing values.

# %%
#  Importing required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv("E:/diabetes_prediction_dataset.csv")  # Replace with your actual filename

#  Display first 5 rows
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
#  Display first 5 rows
df.tail()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0

# %%
# Shape of the dataset
print("Shape of dataset:", df.shape)

# Data types and non-null counts
df.info()
# Out:
# Shape of dataset: (100000, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
# Check for missing values prints out the total number of missing values for each column
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %% [markdown]
# ### 2. **Summary Statistics**
# - Used `df.describe()` to get mean, min, max, standard deviation, etc.
# - Helped identify skewness or irregularity in numerical columns.

# %%
# Summary of numerical columns
df.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %% [markdown]
# ### 3. **Duplicate Values**
# - Checked for and removed duplicate rows using `df.duplicated().sum()` and `df.drop_duplicates()`.

# %%
# Check and remove duplicates
print("Duplicate rows:", df.duplicated().sum())
df = df.drop_duplicates()
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 3854
# Duplicate rows: 0

# %% [markdown]
# ### 4. **Univariate Analysis (Single Variable)**
# - Analyzed distribution of categorical features (`gender`, `smoking_history`, etc.) using `value_counts()` and bar plots.
# - Analyzed numerical features (`age`,`blood_glucose_level`,etc) using histograms and boxplots.

# %%
# Gender distribution
sns.countplot(data=df, x='gender')
plt.title("Gender Distribution")
plt.show()

# %%
sns.countplot(data=df, x='smoking_history', order=df['smoking_history'].value_counts().index)
plt.title("Smoking History")
plt.show()

# %%
# Age distribution
sns.histplot(df['age'], kde=True)
plt.title("Age Distribution")
plt.show()

# %% [markdown]
# ### 5. **Bivariate Analysis (Two Variables)**
# - Used `sns.boxplot()` and `sns.countplot()` to explore relationships between features and the target variable `diabetes`.
# - Example: Compared average BMI and age across diabetes status.

# %%
#Diabetes vs Gender
sns.countplot(x='diabetes', hue='gender', data=df)
plt.title("Diabetes by Gender")
plt.xticks([0,1], ['No Diabetes', 'Diabetes'], rotation=0)
plt.show()

# %%
# Diabetes vs Smoking History
sns.countplot(x='diabetes', hue='smoking_history', data=df)
plt.title("Diabetes by Smoking History")
plt.xticks([0,1], ['No Diabetes', 'Diabetes'], rotation=0)
plt.show()

# %%
# BMI vs Diabetes
sns.boxplot(x='diabetes', y='bmi', data=df)
plt.title("BMI by Diabetes Status")
plt.xticks([0,1], ['No Diabetes', 'Diabetes'], rotation=0)
plt.show()
# Categories:
# Underweight: < 18.5
# Normal: 18.5–24.9
# Overweight: 25–29.9
# Obese: 30+

# %% [markdown]
# ### 6. **Class Balance**
# - Checked how balanced the target variable (`diabetes`) is using `value_counts()`.
# - Noted if class imbalance techniques might be needed during training.
#      - Oversampling minority class (e.g., SMOTE)
#      - Undersampling majority class
#      - Using stratified sampling during training/test split
#      - Choosing proper metrics (like precision, recall, F1-score instead of just accuracy)

# %%
df['diabetes'].value_counts().plot(kind='bar')
plt.title("Diabetes Class Distribution")
plt.xticks([0,1], ['No Diabetes', 'Diabetes'], rotation=0)
plt.show()

# Percentage
print("Class distribution (normalized):")
print(df['diabetes'].value_counts(normalize=True))
# Out:
# Class distribution (normalized):
# diabetes
# 0    0.91178
# 1    0.08822
# Name: proportion, dtype: float64

# %% [markdown]
# ## 📝 Observations:
# - The dataset is mostly clean with no major issues.
# - Some categories in `smoking_history` will br grouped together for simplification.
# - Certain variables like `age`, `BMI`, and `HbA1c_level` showed clear trends with respect to diabetes.
# - Our dataset was imbalanced (~9% positive diabetes cases) and this has to be fix before training model

# %% [markdown]
# # 🧼 Data Preprocessing
#
# ---
#
# ## 🔁 1. Installing scikit-learn (sklearn).
#   - Scikit-learn (often abbreviated as sklearn) is a popular open-source Python library for machine learning that provides a wide range of tools for data preprocessing, model training, evaluation, and deployment.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
import numpy as np

# %% [markdown]
# ## 🔁 2. Merging Categories in Smoking History
#
# We merged some similar categories in the `smoking_history` column to simplify the analysis:
#
# - Replaced `"not current"` and `"ever"` with `"former"`
# - as "former" and "not current" are quite similar. "ever" is a broader term that can include both "current" and "former".

# %%
# Merge smoking history categories
df['smoking_history'] = df['smoking_history'].replace({
    'not current': 'former',
    'ever': 'former'
})
print(df["smoking_history"].unique())
# Out:
# ['never' 'No Info' 'current' 'former']

# %% [markdown]
# ## 🔁 3. Split features and target
# - Features in x and Target(labled column) in y

# %%
X=df.iloc[:, 0:-1].values #select All cols expecet last
Y=df.iloc[:,-1].values #last col with all rows

# %% [markdown]
# ## 🔁 4. Handling Missing Values
#  -  Fills missing values(if any) with mean

# %%
imputer = SimpleImputer(strategy='mean')

X[:, 1:2] = imputer.fit_transform(X[:, 1:2])  # age
X[:, 2:3] = imputer.fit_transform(X[:, 2:3])  # hypertension
X[:, 3:4] = imputer.fit_transform(X[:, 3:4])  # heart_disease
X[:, 5:6] = imputer.fit_transform(X[:, 5:6])  # bmi
X[:, 6:7] = imputer.fit_transform(X[:, 6:7])  # HbA1c_level
X[:, 7:8] = imputer.fit_transform(X[:, 7:8])  # blood_glucose_level

# %% [markdown]
# ## 🔁 5. Label Encoding & One-Hot Encoding
# - Label encoding assigns a unique integer to each category,
# - while one-hot encoding creates binary columns (0 or 1) for each category
# - Label Encoding for Gender & One-Hot Encoding for Smoking_history

# %%
# Label Encoding for Gender (column 0)
from sklearn.preprocessing import LabelEncoder
le_gender = LabelEncoder()
X[:, 0] = le_gender.fit_transform(X[:, 0])  # Male=1, Female=0

# %%
ct = ColumnTransformer(
    transformers=[('encoder', OneHotEncoder(), [4])],
    remainder='passthrough'
)
X = ct.fit_transform(X)

# %% [markdown]
# ## 🔁 6. Splitting Data into Train and Test
#  **When building a machine learning model, we split the dataset into**:
#  - Training Set: Used to train the model.
#  - Testing Set :Used to evaluate the model's performance.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=0)

# %% [markdown]
# ## 🔁 7. Feature Scaling Bringing all features values in comparable ranges.
#  **Why Do We Need Feature Scaling?**
# - Equal Contribution:
# Machine learning algorithms treat all features as equally important unless otherwise specified. Without scaling, features with larger values might dominate the learning process, leading to biased or inaccurate models.
# - Improved Model Performance:
# Scaling can lead to more accurate and generalizable models by ensuring that all features contribute equally to the model's predictions.

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## 🔁 8. Balancing the Training Data using SMOTE
#  **Our dataset was imbalanced (~9% positive diabetes cases).**
# - To fix this, we used SMOTE (Synthetic Minority Oversampling Technique) to generate synthetic samples for the minority class..

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=0)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, Y_train)

# %% [markdown]
# # 🔁 => Applying KNN Algorithm

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# 1. Initialize the model
knn = KNeighborsClassifier(n_neighbors=5)  # You can change K to 3, 7, etc.

# 2. Train the model
knn.fit(X_train_resampled, y_train_resampled)

# 3. Predict on test data
y_pred_knn = knn.predict(X_test)

# 4. Evaluate the model
print("✅ Accuracy Score:", accuracy_score(Y_test, y_pred_knn))
print("\n📊 Confusion Matrix:\n", confusion_matrix(Y_test, y_pred_knn))
print("\n📋 Classification Report:\n", classification_report(Y_test, y_pred_knn))

from sklearn.metrics import classification_report
import pandas as pd

# Convert classification report to dictionary
report = classification_report(Y_test, y_pred_knn, output_dict=True)
df_report = pd.DataFrame(report).transpose()
# Out:
# ✅ Accuracy Score: 0.9099323972958918
#
# 📊 Confusion Matrix:
#  [[16104  1430]
#  [  302  1394]]
#
# 📋 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95     17534
#            1       0.49      0.82      0.62      1696
#
#     accuracy                           0.91     19230
#    macro avg       0.74      0.87      0.78     19230
# weighted avg       0.94      0.91      0.92     19230

# %% [markdown]
# # 📋 KNN Model Evaluation Report
#
# ## ✅ Model: K-Nearest Neighbors (KNN)
#
# We trained a KNN classifier on the resampled (SMOTE-balanced) training data to predict diabetes. After applying preprocessing and feature scaling, the model was evaluated on the original test data.
#
# ---
#
# ## 📊 Evaluation Metrics
#
# **Accuracy Score**: `~90.99%`
# This indicates that 91% of total predictions were correct.
#
# ### 🔹 Confusion Matrix:
# - **True Negatives (TN)**: 16104 — Correctly predicted as non-diabetic
# - **False Positives (FP)**: 1430 — Predicted diabetic, actually not
# - **False Negatives (FN)**: 302 — Predicted non-diabetic, actually diabetic
# - **True Positives (TP)**: 1394 — Correctly predicted as diabetic
#
# |          | Predicted 0 | Predicted 1 |
# |----------|-------------|-------------|
# | Actual 0 | TN:16104    | FP:1430     |
# | Actual 1 | FN:302      | TP:1394     |
#
#
# ### 🔹 Precision , Recall, F1-score
# - **Precision (Diabetes = 0.49)**:Of all patients predicted to have Diabetes, how many really have Diabetes?: Only 49% of positive predictions were correct
# - **Recall (Diabetes = 0.82)**:Of all patients who really have Diabetes, how many were predicted to have Diabetes? 82% of actual diabetes cases were correctly identified
# - **F1-score (Diabetes = 0.62)**: Balance of precision and recall
#
# ### ✅ Why F1 = 0.62 is OK here:
# In medical problems, missing a positive case (e.g., a real diabetic patient) is riskier than flagging a healthy person as diabetic.
#
#  **Because:**
# - model successfully finds most diabetic patients :High Recall (✔️ catching most diabetics)
#
# - Even though it sometimes wrongly flags healthy people (lower precision), it's acceptable for early screening
#
# - The F1-score shows moderate performance
